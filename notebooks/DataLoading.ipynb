# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc
import pandas as pd

from data_loading import DataLoader

# %%
dl = DataLoader(
    data_path='../data/',
)

dl.preprocess_data(
    preprocessing_steps={
        'impute_downshifted_normal_sample': {},
    },
)

adata = dl.adata.copy()

sc.pp.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
# Out:
# loading DA-F08.4_-SEC-pass_v06Sc_ion_LibPGQVal1perc_precdLFQdefFull_prot_preprSc03.tsv
# /Users/sabrina.richter/Code/MS_mv_modelling/notebooks/data_loading.py:61: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   adata_raw = sc.AnnData(data.T, var=vars)
# /Users/sabrina.richter/Code/MS_mv_modelling/notebooks/data_loading.py:69: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata_raw.obs['ID'] = [f'{p[:2]}_{r}_{int(c):02d}' for p, r, c in zip(plate, row, col)]
# (5373, 2703)
# /Users/sabrina.richter/Code/MS_mv_modelling/notebooks/data_loading.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
sc.pl.umap(
    adata, 
    color=['prep_day', 'Platte', 'log Qalb', 'n_genes', 'Diagnosis_group', 'Sex', 'Age'], 
    vmin='p01', vmax='p99'
)
# Out:
# /Users/sabrina.richter/anaconda3/envs/disease_atlas/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /Users/sabrina.richter/anaconda3/envs/disease_atlas/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /Users/sabrina.richter/anaconda3/envs/disease_atlas/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /Users/sabrina.richter/anaconda3/envs/disease_atlas/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
dl = DataLoader(
    data_path='../data/',
)

dl.preprocess_data(
    preprocessing_steps={
        'impute_downshifted_normal_sample': {}, 'combat': {},
    },
)

adata = dl.adata.copy()

sc.pp.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
# Out:
# loading DA-F08.4_-SEC-pass_v06Sc_ion_LibPGQVal1perc_precdLFQdefFull_prot_preprSc03.tsv
# /Users/sabrina.richter/Code/MS_mv_modelling/notebooks/data_loading.py:61: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   adata_raw = sc.AnnData(data.T, var=vars)
# /Users/sabrina.richter/Code/MS_mv_modelling/notebooks/data_loading.py:69: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata_raw.obs['ID'] = [f'{p[:2]}_{r}_{int(c):02d}' for p, r, c in zip(plate, row, col)]
# (5373, 2703)
# /Users/sabrina.richter/Code/MS_mv_modelling/notebooks/data_loading.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
sc.pl.umap(
    adata, 
    color=['prep_day', 'Platte', 'log Qalb', 'n_genes', 'Diagnosis_group', 'Sex', 'Age'], 
    vmin='p01', vmax='p99'
)
# Out:
# /Users/sabrina.richter/anaconda3/envs/disease_atlas/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /Users/sabrina.richter/anaconda3/envs/disease_atlas/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /Users/sabrina.richter/anaconda3/envs/disease_atlas/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /Users/sabrina.richter/anaconda3/envs/disease_atlas/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
