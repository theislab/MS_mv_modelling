# %% [markdown]
# # Example 1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xs = np.array([1, 2, 3, 4, 5])
ys = np.array([5, 4, 3, 2, 1])

# %%
plt.figure(figsize=(5, 3))
plt.plot(xs, ys, "ro-")
plt.xlabel("x")
plt.ylabel("y");
# Out:
# Text(0, 0.5, 'y')
